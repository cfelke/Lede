# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver = webdriver.Chrome()
driver.get('https://arlweb.msha.gov/drs/drshome.htm')

# %%
text_input = driver.find_element_by_name('OperSearch')
text_input.send_keys('dirt')

tick_box = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[3]/td[3]/table/tbody/tr/td/input')
tick_box.click()

# %%
button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %%
operators = driver.find_elements_by_tag_name('tr')
for operator in operators[7:]:
    print(operator.text)
# Out:
# 3503598
# OR  Newberg Rock & Dirt   Newberg Rock & Dirt Surface M  Active  Crushed, Broken Stone NEC
# 0502030
# CO  Allied Dirt Moving Company   Allied Dirt Moving Co Pit & Plant Surface M  Abandoned  Construction Sand and Gravel
# 4801789
# ND  AM Dirtworks & Aggregate Sales   AM Dirtworks & Aggregate Sales Surface M  Abandoned  Construction Sand and Gravel
# 4201449
# UT  Atlas-Dirty Devil Mining   Unit Train Loading Facility Facility C  Abandoned  Coal (Bituminous)
# 4201450
# UT  Atlas-Dirty Devil Mining   Blackie Surface Mine & Prep Plant Surface C  Abandoned  Coal (Bituminous)
# 1002257
# ID  Babe's Dirt Work   Hitt Pit, Inc. Surface M  Abandoned  Construction Sand and Gravel
# 1601167
# LA  Bar-Lin Dirt Company   Bar-Lin Dirt Pit Surface M  Abandoned  Construction Sand and Gravel
# 4103265
# TX  Barber'S Dirt Pit   Barber'S Dirt Pit Surface M  Abandoned  Construction Sand and Gravel
# 1401575
# KS  Bender Sand & Dirt   BENDER SAND & DIRT Surface M  Intermittent  Construction Sand and Gravel
# 1700776
# ME  BERT'S DIRT   BERT'S DIRT Surface M  Abandoned  Construction Sand and Gravel
# 1601251
# LA  Big D Dirt Service Inc   Dorothy V Pit Surface M  Abandoned  Construction Sand and Gravel
# 0301963
# AR  Big Red Dirt Farm LLC   Big Red Dirt Farm Surface M  Abandoned  Construction Sand and Gravel
# 1601082
# LA  Big River Dirt Pit   Big River Dirt Pit Surface M  Abandoned  Construction Sand and Gravel
# 3401751
# OK  Bob Harris Dirt Contracting   Harris Pit Surface M  Abandoned  Construction Sand and Gravel
# 1600916
# LA  Bohannon Sand & Dirt   BOHANNON SAND & DIRT Surface M  Abandoned  Construction Sand and Gravel
# 3401211
# OK  Bratcher'S Sand & Dirt   Eubanks Pit Surface M  Abandoned  Construction Sand and Gravel
# 0301267
# AR  Brewer Dirt Works   Brewer Pit Surface M  Abandoned  Construction Sand and Gravel
# 1600956
# LA  Buck'S Dirt Pit   Buck'S Dirt Pit Surface M  Abandoned  Construction Sand and Gravel
# 2200033
# MS  C & G Dirt Hauling   Laurel Brick & Tile Surface M  Abandoned  Common Clays NEC
# 0504953
# NM  C N C Dirt Movers, Inc.   Foster Canyon Surface M  Abandoned  Construction Sand and Gravel
# 3401929
# OK  Cambridge Dirt Sand and Gravel LLC   Cambridge #1 Surface M  Abandoned  Sand, Industrial NEC
# 1302445
# IA  Central Iowa Dirt & Demo LLC   Woolstock Surface M  Abandoned  Construction Sand and Gravel
# 1601106
# LA  Crowes Trucking & Dirt Pit Services   Crowes Dirt Pit Surface M  Abandoned  Construction Sand and Gravel
# 3400915
# OK  D & H Dirt   D & H Dirt Surface M  Abandoned  Construction Sand and Gravel
# 1600983
# LA  Diez Dirt & Sand Hauling Inc   Amite Acres Dredge Surface M  Abandoned  Construction Sand and Gravel
# 4503200
# WA  Dirt Cheap   Dirt Cheap Surface M  Abandoned  Common Clays NEC
# 3401266
# OK  Dirt Company   Pit #1 Surface M  Abandoned  Construction Sand and Gravel
# 3401468
# DIRTWORKS, INC.
# Dirtworks, Inc.
# Dirty Coal
# Dorchester Dirt Company Inc
# Douglas Dirt Sand & Gravel Company
# Ell Dirt Works LLC.
# Floyd Smith Dirt Pit
# Gary Kelm Dirt Service
# Gerald Fenger/Rock & Dirt Const
# Gerald Illies Gravel & Dirt Company
# Guidry Sand & Dirt Pit Inc
# Harris Dirt Company Inc
# Hatchet Creek Rock & Dirt LLC
# Holley Dirt Company, Inc
# Iske Dirt Sand & Gravel
# J M Lynn Dirtwork
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jarratt Dirt Work and Paving, Inc.
# JBS DIRT, INC.
# Jones Bros Dirt & Paving Contractors Inc
# Krueger Brothers Gravel & Dirt
# Krueger Dirt Werx, Inc.
# L I P Dirt & Trucking
# Lee'S Dirt Pit Inc
# Little-G-Dirt Pit
# Lone Star Dirt & Paving
# Loyd'S Dirt & Gravel
# M R Dirt
# M.C. Dirt LLC
# M.R. Dirt Inc.
# Maurice Dirt & Sand
# Mc Dirt Industries Inc
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Moss Dirt Company
# Moss Dirt Company
# Muckler Fill Dirt & Top Soil
# Nelson & Sons Dirt Haulers Inc
# Nelson'S Dirt Pit
# Nicholson Dirt Contracting
# Nitty Gritty Dirt LLC
# Northest Louisiana Dirt Contractors
# Orvil Carter Dirt Contractor Inc
# Orvil Carter Dirt Contractor Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc.
# P B Dirt Movers, Inc
# P B Dirt Movers, Inc.
# P.B. Dirtmovers
# PAPA'S DIRT WORKES
# Paydirt Exc Inc
# PB Dirt Movers
# PB Dirt Movers Inc.
# PB Dirt Movers, Inc
# Peveto Dirt Pit
# Phil-Dirt Industries, Inc
# Prescott Dirt, LLC
# R & R Dirtworks
# R D Blankenship Dirt Work LLC
# Reeves Dirt Pit Inc
# River Bottom Dirt
# Roe'S Dirt Pit
# Russell Trest-Dirt Contractor
# S J Stahr Dirt Movers Inc
# Sand & Dirt, Inc
# Sand and Dirt, Inc.
# Sierra Rock & Dirt, Inc.
# Simpson Dirtworx llc
# SIMPSON DIRTWORX LLC
# SIMPSON DIRTWORX LLC
# Slay'S Dirt Hauling
# Southside Dirt Company
# Spry's Dirt & Gravel, Inc.
# Stewart Dirt Pit
# Stewart Dirt Work, Inc.
# Sweat'S Dirt Hauling Inc
# Toler Roe Dirt Pit
# Tres Palacios Dirt, Sand & Gravel
# Vogt Dirt Service
# Watson Dirt Sand & Gravel Pit Inc
# Y B Dirt & Loam
# Yarbrough Dirt Pit Inc
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-fa4aabc30504> in <module>()
#       2 for operator in operators[7:]:
#       3     columns = operator.find_elements_by_tag_name('td')
# ----> 4     print(columns[2].text)
#
# IndexError: list index out of range

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
operators = driver.find_elements_by_tag_name('tr')
for operator in operators[7:]:
    column_ID = operator.find_elements_by_tag_name('td')
    print(column_ID[0].text)
# Out:
# 3503598
# 0502030
# 4801789
# 4201449
# 4201450
# 1002257
# 1601167
# 4103265
# 1401575
# 1700776
# 1601251
# 0301963
# 1601082
# 3401751
# 1600916
# 3401211
# 0301267
# 1600956
# 2200033
# 0504953
# 3401929
# 1302445
# 1601106
# 3400915
# 1600983
# 4503200
# 3401266
# 3401468
# 5001797
# 4608254
# 1510279
# 2103723
# 0100776
# 4104016
# 2103914
# 4104757
# 0301729
# 0404851
# 2200734
# 5002028
# 1513393
# 3800602
# 3101630
# 3200860
# 3401762
# 2103517
# 2402626
# 2103181
# 1601124
# 1601150
# 4703427
# 0801306
# 2501216
# 3200965
# 2901371
# 2901544
# 2901709
# 4102355
# 4102420
# 4102869
# 4102951
# 4102958
# 4104876
# 3003502
# 4103258
# 3901432
# 2103556
# 1601250
# 1600908
# 1600953
# 4104185
# 2901536
# 3609624
# 3800709
# 3609931
# 1601257
# 0801275
# 1601379
# 1601380
# 1601381
# 1601134
# 1601165
# 3901042
# 1601194
# 4104054
# 4801674
# 2402474
# 1600920
# 4102955
# 4103107
# 1512530
# 1515619
# 1518318
# 4405366
# 4407196
# 1519685
# 1519799
# 4407379
# 4407003
# 2602570
# 2402503
# 4407296
# 1519273
# 4407270
# 4102682
# 0801259
# 0203332
# 0302015
# 2901986
# 1601127
# 4105017
# 1600986
# 4103324
# 4202013
# 0801417
# 0801371
# 2402115
# 4300748
# 4300768
# 4300776
# 0103209
# 1601159
# 2302283
# 4102586
# 4104475
# 3800617
# 1601234
# 4104648
# 2103518
# 1601292
# 4103429
# 4103264
# Total Number of Mines Found:  132

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
operators = driver.find_elements_by_tag_name('tr')
rows = []

for operator in operators[7:]:
    row = {}
    
    column_ID = operator.find_elements_by_tag_name('td')[0]
    #print(column_ID.text)
    row['column_ID'] = column_ID.text
    
    column_state = operator.find_elements_by_tag_name('td')[1]
    #print(column_state.text)
    row['column_state'] = column_state.text
    
    column_name = operator.find_elements_by_tag_name('td')[2]
    #print(column_name.text)
    row['column_name'] = column_name.text
    
    column_mine_name = operator.find_elements_by_tag_name('td')[3]
    #print(column_mine_name.text)
    row['column_mine_name'] = column_mine_name.text
        
    column_type = operator.find_elements_by_tag_name('td')[4]
    #print(column_type.text)
    row['column_type'] = column_type.text
        
    column_coal_metal = operator.find_elements_by_tag_name('td')[5]
    #print(column_coal_metal.text)
    row['column_coal_metal'] = column_coal_metal.text
    
    column_status = operator.find_elements_by_tag_name('td')[6]
    #print(column_status.text)
    row['column_status'] = column_status.text
    
    column_commodity = operator.find_elements_by_tag_name('td')[7]
    #print(column_commodity.text)
    row['column_commodity'] = column_commodity.text
    
    print('My dictionary looks like', row)
    rows.append(row)
# Out:
# My dictionary looks like {'column_ID': '3503598', 'column_state': 'OR ', 'column_name': 'Newberg Rock & Dirt  ', 'column_mine_name': 'Newberg Rock & Dirt', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Active ', 'column_commodity': 'Crushed, Broken Stone NEC '}
# My dictionary looks like {'column_ID': '0502030', 'column_state': 'CO ', 'column_name': 'Allied Dirt Moving Company  ', 'column_mine_name': 'Allied Dirt Moving Co Pit & Plant', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4801789', 'column_state': 'ND ', 'column_name': 'AM Dirtworks & Aggregate Sales  ', 'column_mine_name': 'AM Dirtworks & Aggregate Sales', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4201449', 'column_state': 'UT ', 'column_name': 'Atlas-Dirty Devil Mining  ', 'column_mine_name': 'Unit Train Loading Facility', 'column_type': 'Facility', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '4201450', 'column_state': 'UT ', 'column_name': 'Atlas-Dirty Devil Mining  ', 'column_mine_name': 'Blackie Surface Mine & Prep Plant', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '1002257', 'column_state': 'ID ', 'column_name': "Babe's Dirt Work  ", 'column_mine_name': 'Hitt Pit, Inc.', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601167', 'column_state': 'LA ', 'column_name': 'Bar-Lin Dirt Company  ', 'column_mine_name': 'Bar-Lin Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4103265', 'column_state': 'TX ', 'column_name': "Barber'S Dirt Pit  ", 'column_mine_name': "Barber'S Dirt Pit", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1401575', 'column_state': 'KS ', 'column_name': 'Bender Sand & Dirt  ', 'column_mine_name': 'BENDER SAND & DIRT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1700776', 'column_state': 'ME ', 'column_name': "BERT'S DIRT  ", 'column_mine_name': "BERT'S DIRT", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601251', 'column_state': 'LA ', 'column_name': 'Big D Dirt Service Inc  ', 'column_mine_name': 'Dorothy V Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0301963', 'column_state': 'AR ', 'column_name': 'Big Red Dirt Farm LLC  ', 'column_mine_name': 'Big Red Dirt Farm', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601082', 'column_state': 'LA ', 'column_name': 'Big River Dirt Pit  ', 'column_mine_name': 'Big River Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3401751', 'column_state': 'OK ', 'column_name': 'Bob Harris Dirt Contracting  ', 'column_mine_name': 'Harris Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1600916', 'column_state': 'LA ', 'column_name': 'Bohannon Sand & Dirt  ', 'column_mine_name': 'BOHANNON SAND & DIRT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3401211', 'column_state': 'OK ', 'column_name': "Bratcher'S Sand & Dirt  ", 'column_mine_name': 'Eubanks Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0301267', 'column_state': 'AR ', 'column_name': 'Brewer Dirt Works  ', 'column_mine_name': 'Brewer Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1600956', 'column_state': 'LA ', 'column_name': "Buck'S Dirt Pit  ", 'column_mine_name': "Buck'S Dirt Pit", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2200033', 'column_state': 'MS ', 'column_name': 'C & G Dirt Hauling  ', 'column_mine_name': 'Laurel Brick & Tile', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Common Clays NEC '}
# My dictionary looks like {'column_ID': '0504953', 'column_state': 'NM ', 'column_name': 'C N C Dirt Movers, Inc.  ', 'column_mine_name': 'Foster Canyon', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3401929', 'column_state': 'OK ', 'column_name': 'Cambridge Dirt Sand and Gravel LLC  ', 'column_mine_name': 'Cambridge #1', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Sand, Industrial NEC '}
# My dictionary looks like {'column_ID': '1302445', 'column_state': 'IA ', 'column_name': 'Central Iowa Dirt & Demo LLC  ', 'column_mine_name': 'Woolstock', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601106', 'column_state': 'LA ', 'column_name': 'Crowes Trucking & Dirt Pit Services  ', 'column_mine_name': 'Crowes Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3400915', 'column_state': 'OK ', 'column_name': 'D & H Dirt  ', 'column_mine_name': 'D & H Dirt', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1600983', 'column_state': 'LA ', 'column_name': 'Diez Dirt & Sand Hauling Inc  ', 'column_mine_name': 'Amite Acres Dredge', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4503200', 'column_state': 'WA ', 'column_name': 'Dirt Cheap  ', 'column_mine_name': 'Dirt Cheap', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Common Clays NEC '}
# My dictionary looks like {'column_ID': '3401266', 'column_state': 'OK ', 'column_name': 'Dirt Company  ', 'column_mine_name': 'Pit #1', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3401468', 'column_state': 'OK ', 'column_name': 'Dirt Company  ', 'column_mine_name': 'Hicks Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '5001797', 'column_state': 'AK ', 'column_name': 'Dirt Company  ', 'column_mine_name': 'Bush Pilot', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4608254', 'column_state': 'WV ', 'column_name': 'Dirt Con  ', 'column_mine_name': 'Hog Lick Quarry', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '1510279', 'column_state': 'KY ', 'column_name': 'Dirt Diggers Inc  ', 'column_mine_name': 'Debco Mine', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '2103723', 'column_state': 'MN ', 'column_name': 'Dirt Doctor Inc  ', 'column_mine_name': 'Rock Lake Plant', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0100776', 'column_state': 'AL ', 'column_name': 'Dirt Inc  ', 'column_mine_name': 'Harrison Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Common Clays NEC '}
# My dictionary looks like {'column_ID': '4104016', 'column_state': 'TX ', 'column_name': 'Dirt Pit  ', 'column_mine_name': 'THE DIRT PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2103914', 'column_state': 'MN ', 'column_name': 'Dirt Work Specialists LLC  ', 'column_mine_name': 'Astec Plant', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4104757', 'column_state': 'TX ', 'column_name': 'Dirt Works  ', 'column_mine_name': 'Portable #1', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0301729', 'column_state': 'AR ', 'column_name': 'Dirtco Inc  ', 'column_mine_name': 'DIRTCO INC', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0404851', 'column_state': 'CA ', 'column_name': 'Dirtman Trucking  ', 'column_mine_name': 'Dirtman Sand & Gravel #2', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2200734', 'column_state': 'MS ', 'column_name': 'DIRTWORKS, INC.  ', 'column_mine_name': 'DIRTWORKS, INC.', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '5002028', 'column_state': 'AK ', 'column_name': 'Dirtworks, Inc.  ', 'column_mine_name': 'Dirtworks, Inc.', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1513393', 'column_state': 'KY ', 'column_name': 'Dirty Coal  ', 'column_mine_name': 'No 1 Surface', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '3800602', 'column_state': 'SC ', 'column_name': 'Dorchester Dirt Company Inc  ', 'column_mine_name': 'DIAMOND MINE #3', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3101630', 'column_state': 'NC ', 'column_name': 'Douglas Dirt Sand & Gravel Company  ', 'column_mine_name': 'Mccormick Pit & Plant', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Granite '}
# My dictionary looks like {'column_ID': '3200860', 'column_state': 'ND ', 'column_name': 'Ell Dirt Works LLC.  ', 'column_mine_name': 'Portable Jaw #1', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3401762', 'column_state': 'OK ', 'column_name': 'Floyd Smith Dirt Pit  ', 'column_mine_name': 'Floyd Smith Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Dimension Stone NEC '}
# My dictionary looks like {'column_ID': '2103517', 'column_state': 'MN ', 'column_name': 'Gary Kelm Dirt Service  ', 'column_mine_name': 'Screener', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2402626', 'column_state': 'MT ', 'column_name': 'Gerald Fenger/Rock & Dirt Const  ', 'column_mine_name': 'Aden Ward', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2103181', 'column_state': 'MN ', 'column_name': 'Gerald Illies Gravel & Dirt Company  ', 'column_mine_name': 'PORTABLE CRUSHER', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601124', 'column_state': 'LA ', 'column_name': 'Guidry Sand & Dirt Pit Inc  ', 'column_mine_name': 'Guidry Sand & Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601150', 'column_state': 'LA ', 'column_name': 'Harris Dirt Company Inc  ', 'column_mine_name': 'Harris Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4703427', 'column_state': 'WI ', 'column_name': 'Hatchet Creek Rock & Dirt LLC  ', 'column_mine_name': 'Hatchet Creek Rock & Dirt LLC', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0801306', 'column_state': 'FL ', 'column_name': 'Holley Dirt Company, Inc  ', 'column_mine_name': 'River Road Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Active ', 'column_commodity': 'Sand, Common '}
# My dictionary looks like {'column_ID': '2501216', 'column_state': 'NE ', 'column_name': 'Iske Dirt Sand & Gravel  ', 'column_mine_name': 'Iske Dirt Sand & Gravel', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3200965', 'column_state': 'ND ', 'column_name': 'J M Lynn Dirtwork  ', 'column_mine_name': 'Johnson Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2901371', 'column_state': 'NM ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Diel Screening Plant', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2901544', 'column_state': 'NM ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Cortez Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2901709', 'column_state': 'NM ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Skaggs Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Stone NEC '}
# My dictionary looks like {'column_ID': '4102355', 'column_state': 'TX ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Jacobson Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '4102420', 'column_state': 'TX ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Black Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '4102869', 'column_state': 'TX ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Bailey Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Stone NEC '}
# My dictionary looks like {'column_ID': '4102951', 'column_state': 'TX ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Toscosa Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '4102958', 'column_state': 'TX ', 'column_name': 'Jake Diel Dirt & Paving Inc  ', 'column_mine_name': 'Four Way Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4104876', 'column_state': 'TX ', 'column_name': 'Jarratt Dirt Work and Paving, Inc.  ', 'column_mine_name': 'Portable Screening Plant #1', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Stone NEC '}
# My dictionary looks like {'column_ID': '3003502', 'column_state': 'NY ', 'column_name': 'JBS DIRT, INC.  ', 'column_mine_name': 'SHAMROCK PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4103258', 'column_state': 'TX ', 'column_name': 'Jones Bros Dirt & Paving Contractors Inc  ', 'column_mine_name': 'Barstow Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '3901432', 'column_state': 'SD ', 'column_name': 'Krueger Brothers Gravel & Dirt  ', 'column_mine_name': 'PORTABLE SCREENER', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2103556', 'column_state': 'MN ', 'column_name': 'Krueger Dirt Werx, Inc.  ', 'column_mine_name': 'Krueger Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601250', 'column_state': 'LA ', 'column_name': 'L I P Dirt & Trucking  ', 'column_mine_name': 'L I P Dirt & Trucking', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1600908', 'column_state': 'LA ', 'column_name': "Lee'S Dirt Pit Inc  ", 'column_mine_name': "Lee'S Dirt Pit", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1600953', 'column_state': 'LA ', 'column_name': 'Little-G-Dirt Pit  ', 'column_mine_name': 'Little-G-Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4104185', 'column_state': 'TX ', 'column_name': 'Lone Star Dirt & Paving  ', 'column_mine_name': 'Lone Star Crusher', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Stone NEC '}
# My dictionary looks like {'column_ID': '2901536', 'column_state': 'NM ', 'column_name': "Loyd'S Dirt & Gravel  ", 'column_mine_name': "LOYD'S PIT", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3609624', 'column_state': 'PA ', 'column_name': 'M R Dirt  ', 'column_mine_name': 'Forbes Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Temporarily Idled ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3800709', 'column_state': 'SC ', 'column_name': 'M.C. Dirt LLC  ', 'column_mine_name': 'Middleton Site', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Sand, Common '}
# My dictionary looks like {'column_ID': '3609931', 'column_state': 'PA ', 'column_name': 'M.R. Dirt Inc.  ', 'column_mine_name': 'Camptown Quarry', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Dimension Stone NEC '}
# My dictionary looks like {'column_ID': '1601257', 'column_state': 'LA ', 'column_name': 'Maurice Dirt & Sand  ', 'column_mine_name': 'Maurice Dirt And Sand', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0801275', 'column_state': 'FL ', 'column_name': 'Mc Dirt Industries Inc  ', 'column_mine_name': 'BELLVIEW', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601379', 'column_state': 'LA ', 'column_name': 'Mike Duhon Dirt Pit  ', 'column_mine_name': 'REDS PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601380', 'column_state': 'LA ', 'column_name': 'Mike Duhon Dirt Pit  ', 'column_mine_name': 'WAINWRIGHT PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601381', 'column_state': 'LA ', 'column_name': 'Mike Duhon Dirt Pit  ', 'column_mine_name': 'COX PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601134', 'column_state': 'LA ', 'column_name': 'Moss Dirt Company  ', 'column_mine_name': 'Cook Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601165', 'column_state': 'LA ', 'column_name': 'Moss Dirt Company  ', 'column_mine_name': 'Moss Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '3901042', 'column_state': 'SD ', 'column_name': 'Muckler Fill Dirt & Top Soil  ', 'column_mine_name': 'Hoffman Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601194', 'column_state': 'LA ', 'column_name': 'Nelson & Sons Dirt Haulers Inc  ', 'column_mine_name': 'Nelson & Sons Dirt Haulers Incorporated', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4104054', 'column_state': 'TX ', 'column_name': "Nelson'S Dirt Pit  ", 'column_mine_name': "NELSON'S DIRT PIT", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4801674', 'column_state': 'WY ', 'column_name': 'Nicholson Dirt Contracting  ', 'column_mine_name': 'Eagle One', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2402474', 'column_state': 'MT ', 'column_name': 'Nitty Gritty Dirt LLC  ', 'column_mine_name': 'Rolling Glen Ranch Sand and Gravel', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1600920', 'column_state': 'LA ', 'column_name': 'Northest Louisiana Dirt Contractors  ', 'column_mine_name': 'Calhoun And Mcguire Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4102955', 'column_state': 'TX ', 'column_name': 'Orvil Carter Dirt Contractor Inc  ', 'column_mine_name': 'Ed Meek Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '4103107', 'column_state': 'TX ', 'column_name': 'Orvil Carter Dirt Contractor Inc  ', 'column_mine_name': 'Seitz Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '1512530', 'column_state': 'KY ', 'column_name': 'P B Dirt Movers Inc  ', 'column_mine_name': 'No 1 Surface', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '1515619', 'column_state': 'KY ', 'column_name': 'P B Dirt Movers Inc  ', 'column_mine_name': 'No 5 Surface', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '1518318', 'column_state': 'KY ', 'column_name': 'P B Dirt Movers Inc  ', 'column_mine_name': 'Biggs No 1', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '4405366', 'column_state': 'VA ', 'column_name': 'P B Dirt Movers Inc  ', 'column_mine_name': 'No 1 Strip', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '4407196', 'column_state': 'VA ', 'column_name': 'P B Dirt Movers Inc  ', 'column_mine_name': 'No 2', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '1519685', 'column_state': 'KY ', 'column_name': 'P B Dirt Movers Inc.  ', 'column_mine_name': 'Fedscreek Refuse Pile', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '1519799', 'column_state': 'KY ', 'column_name': 'P B Dirt Movers, Inc  ', 'column_mine_name': 'Fedscreek Surface', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Active ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '4407379', 'column_state': 'VA ', 'column_name': 'P B Dirt Movers, Inc.  ', 'column_mine_name': 'No. 3', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'New Mine ', 'column_commodity': ' '}
# My dictionary looks like {'column_ID': '4407003', 'column_state': 'VA ', 'column_name': 'P.B. Dirtmovers  ', 'column_mine_name': 'No 2', 'column_type': 'Underground', 'column_coal_metal': 'C ', 'column_status': 'Abandoned* ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '2602570', 'column_state': 'NV ', 'column_name': "PAPA'S DIRT WORKES  ", 'column_mine_name': 'COUNTY FAIRE TEMP GRAVEL PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2402503', 'column_state': 'MT ', 'column_name': 'Paydirt Exc Inc  ', 'column_mine_name': 'Robison Mine', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4407296', 'column_state': 'VA ', 'column_name': 'PB Dirt Movers  ', 'column_mine_name': 'Mine No. 6', 'column_type': 'Underground', 'column_coal_metal': 'C ', 'column_status': 'Temporarily Idled ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '1519273', 'column_state': 'KY ', 'column_name': 'PB Dirt Movers Inc.  ', 'column_mine_name': 'Blair Face Up', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '4407270', 'column_state': 'VA ', 'column_name': 'PB Dirt Movers, Inc  ', 'column_mine_name': 'Surface Mine No. 1', 'column_type': 'Surface', 'column_coal_metal': 'C ', 'column_status': 'Abandoned ', 'column_commodity': 'Coal (Bituminous) '}
# My dictionary looks like {'column_ID': '4102682', 'column_state': 'TX ', 'column_name': 'Peveto Dirt Pit  ', 'column_mine_name': 'Peveto Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0801259', 'column_state': 'FL ', 'column_name': 'Phil-Dirt Industries, Inc  ', 'column_mine_name': 'PIT #1', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0203332', 'column_state': 'AZ ', 'column_name': 'Prescott Dirt, LLC  ', 'column_mine_name': 'Sandretto Drive', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0302015', 'column_state': 'AR ', 'column_name': 'R & R Dirtworks  ', 'column_mine_name': 'Martins Quarry', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Limestone NEC '}
# My dictionary looks like {'column_ID': '2901986', 'column_state': 'NM ', 'column_name': 'R D Blankenship Dirt Work LLC  ', 'column_mine_name': 'R D BLANKENSHIP DIRT WORK', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Active ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601127', 'column_state': 'LA ', 'column_name': 'Reeves Dirt Pit Inc  ', 'column_mine_name': 'Reeves Dirt Pit Incorporated', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4105017', 'column_state': 'TX ', 'column_name': 'River Bottom Dirt  ', 'column_mine_name': 'River Bottom Dirt', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Sand, Common '}
# My dictionary looks like {'column_ID': '1600986', 'column_state': 'LA ', 'column_name': "Roe'S Dirt Pit  ", 'column_mine_name': "Roe'S Dirt Pit", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4103324', 'column_state': 'TX ', 'column_name': 'Russell Trest-Dirt Contractor  ', 'column_mine_name': 'Pine Ridge Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4202013', 'column_state': 'UT ', 'column_name': 'S J Stahr Dirt Movers Inc  ', 'column_mine_name': 'Stahr Portable Crusher', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0801417', 'column_state': 'FL ', 'column_name': 'Sand & Dirt, Inc  ', 'column_mine_name': 'Molino Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Active ', 'column_commodity': 'Sand, Common '}
# My dictionary looks like {'column_ID': '0801371', 'column_state': 'FL ', 'column_name': 'Sand and Dirt, Inc.  ', 'column_mine_name': 'CENTURY PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Sand, Common '}
# My dictionary looks like {'column_ID': '2402115', 'column_state': 'MT ', 'column_name': 'Sierra Rock & Dirt, Inc.  ', 'column_mine_name': 'Sierra Rock & Dirt Inc', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4300748', 'column_state': 'VT ', 'column_name': 'Simpson Dirtworx llc  ', 'column_mine_name': 'Simpson Sand and Gravel', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4300768', 'column_state': 'VT ', 'column_name': 'SIMPSON DIRTWORX LLC  ', 'column_mine_name': 'Pettibone Jaw Crusher', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4300776', 'column_state': 'VT ', 'column_name': 'SIMPSON DIRTWORX LLC  ', 'column_mine_name': 'Chieftan 1400', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '0103209', 'column_state': 'AL ', 'column_name': "Slay'S Dirt Hauling  ", 'column_mine_name': 'SLAY PIT', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601159', 'column_state': 'LA ', 'column_name': 'Southside Dirt Company  ', 'column_mine_name': 'Southside Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2302283', 'column_state': 'MO ', 'column_name': "Spry's Dirt & Gravel, Inc.  ", 'column_mine_name': "Mike's Money Pit", 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4102586', 'column_state': 'TX ', 'column_name': 'Stewart Dirt Pit  ', 'column_mine_name': 'Stewart Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4104475', 'column_state': 'TX ', 'column_name': 'Stewart Dirt Work, Inc.  ', 'column_mine_name': 'Stewart Dirt Work Inc - Hanna Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Crushed, Broken Stone NEC '}
# My dictionary looks like {'column_ID': '3800617', 'column_state': 'SC ', 'column_name': "Sweat'S Dirt Hauling Inc  ", 'column_mine_name': 'Highway 642 Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601234', 'column_state': 'LA ', 'column_name': 'Toler Roe Dirt Pit  ', 'column_mine_name': 'Toler Roe Dirt Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4104648', 'column_state': 'TX ', 'column_name': 'Tres Palacios Dirt, Sand & Gravel  ', 'column_mine_name': 'La Calichera Pit', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '2103518', 'column_state': 'MN ', 'column_name': 'Vogt Dirt Service  ', 'column_mine_name': 'Crusher', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Intermittent ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '1601292', 'column_state': 'LA ', 'column_name': 'Watson Dirt Sand & Gravel Pit Inc  ', 'column_mine_name': 'ADDISON LEASE', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4103429', 'column_state': 'TX ', 'column_name': 'Y B Dirt & Loam  ', 'column_mine_name': 'Y B Mine', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# My dictionary looks like {'column_ID': '4103264', 'column_state': 'TX ', 'column_name': 'Yarbrough Dirt Pit Inc  ', 'column_mine_name': 'Yarbrough Dirt Pit #1', 'column_type': 'Surface', 'column_coal_metal': 'M ', 'column_status': 'Abandoned ', 'column_commodity': 'Construction Sand and Gravel '}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-1804b68727b4> in <module>()
#       9     row['column_ID'] = column_ID.text
#      10
# ---> 11     column_state = operator.find_elements_by_tag_name('td')[1]
#      12     #print(column_state.text)
#      13     row['column_state'] = column_state.text
#
# IndexError: list index out of range

# %% [markdown]
# # Save that to a CSV named `dirt-operators.csv`

# %%
df = pd.DataFrame(rows)
df.head(5)
# Out:
#   column_ID column_coal_metal               column_commodity  \
# 0   3503598                M      Crushed, Broken Stone NEC
# 1   0502030                M   Construction Sand and Gravel
# 2   4801789                M   Construction Sand and Gravel
# 3   4201449                C              Coal (Bituminous)
# 4   4201450                C              Coal (Bituminous)
#
#                     column_mine_name                       column_name  \
# 0                Newberg Rock & Dirt             Newberg Rock & Dirt
# 1  Allied Dirt Moving Co Pit & Plant      Allied Dirt Moving Company
# 2     AM Dirtworks & Aggregate Sales  AM Dirtworks & Aggregate Sales
# 3        Unit Train Loading Facility        Atlas-Dirty Devil Mining
# 4  Blackie Surface Mine & Prep Plant        Atlas-Dirty Devil Mining
#
#   column_state column_status column_type
# 0          OR        Active      Surface
# 1          CO     Abandoned      Surface
# 2          ND     Abandoned      Surface
# 3          UT     Abandoned     Facility
# 4          UT     Abandoned      Surface

# %%
df.to_csv('dirt_operators.csv', index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
df = pd.read_csv('dirt_operators.csv')
df.head(5)
# Out:
#    column_ID column_coal_metal               column_commodity  \
# 0    3503598                M      Crushed, Broken Stone NEC
# 1     502030                M   Construction Sand and Gravel
# 2    4801789                M   Construction Sand and Gravel
# 3    4201449                C              Coal (Bituminous)
# 4    4201450                C              Coal (Bituminous)
#
#                     column_mine_name                       column_name  \
# 0                Newberg Rock & Dirt             Newberg Rock & Dirt
# 1  Allied Dirt Moving Co Pit & Plant      Allied Dirt Moving Company
# 2     AM Dirtworks & Aggregate Sales  AM Dirtworks & Aggregate Sales
# 3        Unit Train Loading Facility        Atlas-Dirty Devil Mining
# 4  Blackie Surface Mine & Prep Plant        Atlas-Dirty Devil Mining
#
#   column_state column_status column_type
# 0          OR        Active      Surface
# 1          CO     Abandoned      Surface
# 2          ND     Abandoned      Surface
# 3          UT     Abandoned     Facility
# 4          UT     Abandoned      Surface
